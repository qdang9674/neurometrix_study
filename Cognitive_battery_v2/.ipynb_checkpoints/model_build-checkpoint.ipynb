# %% [markdown]
# # Import

# %%
#!jupyter nbconvert --to script model_build.ipynb

import csv
import json
import pywt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import neurokit2 as nk
from scipy.signal import butter, filtfilt
from scipy.signal import resample
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr, spearmanr, linregress
from sklearn.preprocessing import StandardScaler
import random
import tensorflow as tf
from tqdm.notebook import tqdm
from tensorflow.python.client import device_lib
import matplotlib.colors as mcolors
import random

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, accuracy_score, matthews_corrcoef
# Out:
# 2024-09-05 22:48:38.358551: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-05 22:48:38.377573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-05 22:48:38.401402: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-05 22:48:38.401424: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-05 22:48:38.416972: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-05 22:48:39.543311: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print(tf.__version__)
# Out:
# 2.16.2

# %%
tf.config.experimental.list_physical_devices('GPU')
device_lib.list_local_devices()
# Out:
# 2024-09-05 22:48:46.760369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:0 with 22757 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:1b:00.0, compute capability: 7.5
# 2024-09-05 22:48:46.762009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:1 with 22757 MB memory:  -> device: 1, name: Quadro RTX 6000, pci bus id: 0000:1c:00.0, compute capability: 7.5
# 2024-09-05 22:48:46.763463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:2 with 22757 MB memory:  -> device: 2, name: Quadro RTX 6000, pci bus id: 0000:1d:00.0, compute capability: 7.5
# 2024-09-05 22:48:46.764569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:3 with 22757 MB memory:  -> device: 3, name: Quadro RTX 6000, pci bus id: 0000:1e:00.0, compute capability: 7.5
# 2024-09-05 22:48:46.765643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:4 with 22757 MB memory:  -> device: 4, name: Quadro RTX 6000, pci bus id: 0000:3d:00.0, compute capability: 7.5
# 2024-09-05 22:48:46.766769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /dev
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 10369053690386174783
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 15415892994395658013
#  physical_device_desc: "device: 0, name: Quadro RTX 6000, pci bus id: 0000:1b:00.0, compute capability: 7.5"
#  xla_global_id: 416903419,
#  name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 14541221941914528074
#  physical_device_desc: "device: 1, name: Quadro RTX 6000, pci bus id: 0000:1c:00.0, compute capability: 7.5"
#  xla_global_id: 2144165316,
#  name: "/device:GPU:2"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 15614779658039761040
#  physical_device_desc: "device: 2, name: Quadro RTX 6000, pci bus id: 0000:1d:00.0, compute capability: 7.5"
#  xla_global_id: 1651660799,
#  name: "/device:GPU:3"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 13901277610456040854
#  physical_device_desc: "device: 3, name: Quadro RTX 6000, pci bus id: 0000:1e:00.0, compute capability: 7.5"
#  xla_global_id: 878896533,
#  name: "/device:GPU:4"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 3022690535976700988
#  physical_device_desc: "device: 4, name: Quadro RTX 6000, pci bus id: 0000:3d:00.0, compute capability: 7.5"
#  xla_global_id: 615190153,
#  name: "/device:GPU:5"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 3139765638266818274
#  physical_device_desc: "device: 5, name: Quadro RTX 6000, pci bus id: 0000:3f:00.0, compute capability: 7.5"
#  xla_global_id: 1769886423,
#  name: "/device:GPU:6"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 17757388592662163501
#  physical_device_desc: "device: 6, name: Quadro RTX 6000, pci bus id: 0000:40:00.0, compute capability: 7.5"
#  xla_global_id: 893286608,
#  name: "/device:GPU:7"
#  device_type: "GPU"
#  memory_limit: 23862837248
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 4353986148395183333
#  physical_device_desc: "device: 7, name: Quadro RTX 6000, pci bus id: 0000:41:00.0, compute capability: 7.5"
#  xla_global_id: 2099794689]
# ice:GPU:5 with 22757 MB memory:  -> device: 5, name: Quadro RTX 6000, pci bus id: 0000:3f:00.0, compute capability: 7.5
# 2024-09-05 22:48:46.767820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:6 with 22757 MB memory:  -> device: 6, name: Quadro RTX 6000, pci bus id: 0000:40:00.0, compute capability: 7.5
# 2024-09-05 22:48:46.768866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:7 with 22757 MB memory:  -> device: 7, name: Quadro RTX 6000, pci bus id: 0000:41:00.0, compute capability: 7.5

# %%
MODEL_NAME = 'lstm'
RUN = 'run5_' + MODEL_NAME+ '/'

CURRENT_DIR = os.getcwd()
DATA_DIR = CURRENT_DIR + '/data/'
MASTER_OUTPUT_DIR = CURRENT_DIR + '/output/'
OUTPUT_DIR = MASTER_OUTPUT_DIR + RUN
print(DATA_DIR)
print(OUTPUT_DIR)
# Out:
# /nfs/ada/jbrook1/users/qdang1/Descartes/Cognitive_battery_dissertation/data/
# /nfs/ada/jbrook1/users/qdang1/Descartes/Cognitive_battery_dissertation/output/run5_lstm/

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# # Load_data

# %%
# Initialize an empty list to store the arrays
X_dict = {}
Y_dict = {}

# Load each file and append the array to the list
for i in range(5):
    X_filename = f'X_fold{i}.npy'
    X_dict[i] = np.load(DATA_DIR + X_filename, allow_pickle=True)

    Y_filename = f'Y_fold{i}.npy'
    Y_dict[i] = np.load(DATA_DIR + Y_filename,  allow_pickle=True)

for i in range(5):
    print(f'i: {i}, X: {X_dict[i].shape}, Y: {Y_dict[i].shape}')
# Out:
# i: 0, X: (577, 9), Y: (577, 2)
# i: 1, X: (620, 9), Y: (620, 2)
# i: 2, X: (679, 9), Y: (679, 2)
# i: 3, X: (604, 9), Y: (604, 2)
# i: 4, X: (582, 9), Y: (582, 2)

# %%
for index in range(5):
    train_list = [0, 1, 2, 3, 4]
    train_list.remove(index)
    test_list = [index]

    print(f'train: {train_list}, test: {test_list}')

    X_train = X_dict[train_list[0]]
    Y_train = Y_dict[train_list[0]]
    X_test =  X_dict[test_list[0]]
    Y_test =  Y_dict[test_list[0]]
    
    for i_train in train_list[1:]:
        X_train = np.concatenate([X_train,X_dict[i_train] ],axis = 0)
        Y_train = np.concatenate([Y_train,Y_dict[i_train] ],axis = 0)

    for i_test in test_list[1:]:
        X_test = np.concatenate([X_test,X_dict[i_test] ],axis = 0)
        Y_test = np.concatenate([Y_test,Y_dict[i_test] ],axis = 0)

    print(f'X_train: {X_train.shape}, Y_train: {Y_train.shape}, X_test : {X_test.shape}, Y_test: {Y_test.shape}')
# Out:
# train: [1, 2, 3, 4], test: [0]
# X_train: (2485, 9), Y_train: (2485, 2), X_test : (577, 9), Y_test: (577, 2)
# train: [0, 2, 3, 4], test: [1]
# X_train: (2442, 9), Y_train: (2442, 2), X_test : (620, 9), Y_test: (620, 2)
# train: [0, 1, 3, 4], test: [2]
# X_train: (2383, 9), Y_train: (2383, 2), X_test : (679, 9), Y_test: (679, 2)
# train: [0, 1, 2, 4], test: [3]
# X_train: (2458, 9), Y_train: (2458, 2), X_test : (604, 9), Y_test: (604, 2)
# train: [0, 1, 2, 3], test: [4]
# X_train: (2480, 9), Y_train: (2480, 2), X_test : (582, 9), Y_test: (582, 2)

# %%
X_train_demo          = np.array(X_train[:,0].tolist()).squeeze(1)
X_train_1_eye         = np.array(X_train[:,1].tolist())
X_train_1_eye_wavelet = np.array(X_train[:,2].tolist())
X_train_1_ecg         = np.array(X_train[:,3].tolist())
X_train_1_ecg_wavelet = np.array(X_train[:,4].tolist())
X_train_2_eye         = np.array(X_train[:,5].tolist())
X_train_2_eye_wavelet = np.array(X_train[:,6].tolist())
X_train_2_ecg         = np.array(X_train[:,7].tolist())
X_train_2_ecg_wavelet = np.array(X_train[:,8].tolist())

# %%
#cliping with 99.5.5% 


X_train_1_eye = np.clip(X_train_1_eye, np.percentile(X_train_1_eye, 0.5), np.percentile(X_train_1_eye, 99.5))
X_train_1_eye_wavelet = np.clip(X_train_1_eye_wavelet, np.percentile(X_train_1_eye_wavelet, 0.5), np.percentile(X_train_1_eye_wavelet, 99.5))
X_train_1_ecg = np.clip(X_train_1_ecg, np.percentile(X_train_1_ecg, 0.5), np.percentile(X_train_1_ecg, 99.5))
X_train_1_ecg_wavelet = np.clip(X_train_1_ecg_wavelet, np.percentile(X_train_1_ecg_wavelet, 0.5), np.percentile(X_train_1_ecg_wavelet, 99.5))
X_train_2_eye = np.clip(X_train_2_eye, np.percentile(X_train_2_eye, 0.5), np.percentile(X_train_2_eye, 99.5))
X_train_2_eye_wavelet = np.clip(X_train_2_eye_wavelet, np.percentile(X_train_2_eye_wavelet, 0.5), np.percentile(X_train_2_eye_wavelet, 99.5))
X_train_2_ecg = np.clip(X_train_2_ecg, np.percentile(X_train_2_ecg, 0.5), np.percentile(X_train_2_ecg, 99.5))
X_train_2_ecg_wavelet = np.clip(X_train_2_ecg_wavelet, np.percentile(X_train_2_ecg_wavelet, 0.5), np.percentile(X_train_2_ecg_wavelet, 99.5))

print(f'demo:          {X_train_demo.shape}\n\
eye_1:         {X_train_1_eye.shape}\neye_1_wavelet: {X_train_1_eye_wavelet.shape}\n\
ecg_1:         {X_train_1_ecg.shape}\necg_1_wavelet: {X_train_1_ecg_wavelet.shape}\n\
eye_2:         {X_train_2_eye.shape}\neye_2_wavelet: {X_train_2_eye_wavelet.shape}\n\
ecg_2:         {X_train_2_ecg.shape}\necg_2_wavelet: {X_train_2_ecg_wavelet.shape}\n')
# Out:
# demo:          (2480, 17)
# eye_1:         (2480, 60000, 5)
# eye_1_wavelet: (2480, 60000, 5)
# ecg_1:         (2480, 60000, 7)
# ecg_1_wavelet: (2480, 60000, 6)
# eye_2:         (2480, 7500, 4)
# eye_2_wavelet: (2480, 7500, 4)
# ecg_2:         (2480, 7500, 7)
# ecg_2_wavelet: (2480, 7500, 6)

# %%
X_test_demo          = np.array(X_test[:,0].tolist()).squeeze(1)
X_test_1_eye         = np.array(X_test[:,1].tolist())
X_test_1_eye_wavelet = np.array(X_test[:,2].tolist())
X_test_1_ecg         = np.array(X_test[:,3].tolist())
X_test_1_ecg_wavelet = np.array(X_test[:,4].tolist())
X_test_2_eye         = np.array(X_test[:,5].tolist())
X_test_2_eye_wavelet = np.array(X_test[:,6].tolist())
X_test_2_ecg         = np.array(X_test[:,7].tolist())
X_test_2_ecg_wavelet = np.array(X_test[:,8].tolist())

# %%
#cliping with 99.5% 

X_test_1_eye = np.clip(X_test_1_eye, np.percentile(X_test_1_eye, 0.5), np.percentile(X_test_1_eye, 99.5))
X_test_1_eye_wavelet = np.clip(X_test_1_eye_wavelet, np.percentile(X_test_1_eye_wavelet, 0.5), np.percentile(X_test_1_eye_wavelet, 99.5))
X_test_1_ecg = np.clip(X_test_1_ecg, np.percentile(X_test_1_ecg, 0.5), np.percentile(X_test_1_ecg, 99.5))
X_test_1_ecg_wavelet = np.clip(X_test_1_ecg_wavelet, np.percentile(X_test_1_ecg_wavelet, 0.5), np.percentile(X_test_1_ecg_wavelet, 99.5))
X_test_2_eye = np.clip(X_test_2_eye, np.percentile(X_test_2_eye, 0.5), np.percentile(X_test_2_eye, 99.5))
X_test_2_eye_wavelet = np.clip(X_test_2_eye_wavelet, np.percentile(X_test_2_eye_wavelet, 0.5), np.percentile(X_test_2_eye_wavelet, 99.5))
X_test_2_ecg = np.clip(X_test_2_ecg, np.percentile(X_test_2_ecg, 0.5), np.percentile(X_test_2_ecg, 99.5))
X_test_2_ecg_wavelet = np.clip(X_test_2_ecg_wavelet, np.percentile(X_test_2_ecg_wavelet, 0.5), np.percentile(X_test_2_ecg_wavelet, 99.5))




print(f'demo:          {X_test_demo.shape}\n\
eye_1:         {X_test_1_eye.shape}\neye_1_wavelet: {X_test_1_eye_wavelet.shape}\n\
ecg_1:         {X_test_1_ecg.shape}\necg_1_wavelet: {X_test_1_ecg_wavelet.shape}\n\
eye_2:         {X_test_2_eye.shape}\neye_2_wavelet: {X_test_2_eye_wavelet.shape}\n\
ecg_2:         {X_test_2_ecg.shape}\necg_2_wavelet: {X_test_2_ecg_wavelet.shape}\n')
# Out:
# demo:          (582, 17)
# eye_1:         (582, 60000, 5)
# eye_1_wavelet: (582, 60000, 5)
# ecg_1:         (582, 60000, 7)
# ecg_1_wavelet: (582, 60000, 6)
# eye_2:         (582, 7500, 4)
# eye_2_wavelet: (582, 7500, 4)
# ecg_2:         (582, 7500, 7)
# ecg_2_wavelet: (582, 7500, 6)

# %%
Y_train_dif         = np.array(Y_train[:,0].tolist())
Y_train_acc         = np.array(Y_train[:,1].tolist())



print(f'Difficulty:       {Y_train_dif.shape}\nAccuracy:         {Y_train_acc.shape}')
# Out:
# Difficulty:       (2480,)
# Accuracy:         (2480,)

# %%
Y_test_dif         = np.array(Y_test[:,0].tolist())
Y_test_acc         = np.array(Y_test[:,1].tolist())



print(f'Difficulty:       {Y_test_dif.shape}\nAccuracy:         {Y_test_acc.shape}')
# Out:
# Difficulty:       (582,)
# Accuracy:         (582,)

# %%
EPOCHS = 200
BATCH_SIZE = 64
PATIENCE = 20

# %% [markdown]
# # Eye model

# %% [markdown]
# ## Model Build

# %%
def custom_CNN_layer(input_layer, start_neuron = 16, kernel_size=9, strides_size=1, max_pool_size=5, dropout=0.3, padding='valid'):
    cnn_layer = tf.keras.layers.Conv1D(start_neuron, kernel_size, strides=strides_size,  padding=padding, activation=tf.keras.layers.LeakyReLU(),kernel_regularizer=tf.keras.regularizers.l2(0.01))(input_layer)
    #cnn_layer = tf.keras.layers.Conv1D(start_neuron, kernel_size, strides=strides_size,  padding=padding, activation=tf.keras.layers.LeakyReLU(),kernel_regularizer=tf.keras.regularizers.l2(0.01))(cnn_layer)
    cnn_layer = tf.keras.layers.MaxPool1D(max_pool_size,  padding=padding)(cnn_layer)
    cnn_layer = tf.keras.layers.BatchNormalization()(cnn_layer)
    cnn_layer = tf.keras.layers.Dropout(dropout)(cnn_layer)
    return cnn_layer

# %%
# #create model
# def baseline_CNN(shape, start_neuron = 16, kernel_size=9, strides_size=1, max_pool_size=5, dropout=0.3, padding='valid'):    

#     input_layer_demo     = tf.keras.Input((shape[1],), name='input_demo') 
#     input_layer_baseline = tf.keras.Input((shape[3], shape[4]), name='input_baseline') 
#     input_layer_samples  = tf.keras.Input((shape[6], shape[7]), name='input_sample') 

#     #baseline

#     conv_baseline = custom_CNN_layer(input_layer_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')

#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 4, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_baseline = tf.keras.layers.Flatten()(conv_baseline)
#     # lstm_1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron, return_sequences=True))(conv_2)
#     # lstm_1 = tf.keras.layers.Dropout(dropout)(lstm_1)

#     # lstm_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(lstm_1)
#     # lstm_2 = tf.keras.layers.Dropout(dropout)(lstm_2)
#     # lstm_2 = tf.keras.layers.Flatten()(lstm_2)

#     #samples
#     conv_sample  = custom_CNN_layer(input_layer_samples, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
#     conv_sample  = custom_CNN_layer(conv_sample, start_neuron , kernel_size =  3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
#     conv_sample  = custom_CNN_layer(conv_sample, start_neuron , kernel_size =  3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')

#     conv_sample  = custom_CNN_layer(conv_sample, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_sample  = custom_CNN_layer(conv_sample, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_sample  = custom_CNN_layer(conv_sample, start_neuron * 4, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#     conv_sample = tf.keras.layers.Flatten()(conv_sample)
    
#     concat_layer = tf.keras.layers.Concatenate()([conv_baseline, conv_sample, input_layer_demo])
    
#     output_layer = tf.keras.layers.Dense(start_neuron*8,activation=tf.keras.layers.LeakyReLU())(concat_layer)
#     output_layer = tf.keras.layers.Dropout(dropout)(output_layer)
#     output_layer = tf.keras.layers.Dense(start_neuron*8,activation=tf.keras.layers.LeakyReLU())(output_layer)
#     output_layer = tf.keras.layers.Dropout(dropout)(output_layer)
    
#     output_0 = tf.keras.layers.Dense(3, activation='softmax', name='difficulty')(output_layer)


#     model = tf.keras.Model(inputs=[input_layer_demo, input_layer_baseline, input_layer_samples], outputs=[output_0])
#     #loss_weights = [scaling_factors[0]*5,scaling_factors[1],scaling_factors[2],scaling_factors[3],scaling_factors[4]]   
    
#     model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     #model.compile(optimizer = 'adam',loss = ['mae','mae','mae','mae','mae'],loss_weights=loss_weights)
#     return model

# %%
#create model
def baseline_CNN(shape, start_neuron = 16, kernel_size=9, strides_size=1, max_pool_size=5, dropout=0.3, padding='valid'):    

    input_layer_demo     = tf.keras.Input((shape[1],), name='input_demo') 
    input_layer_baseline = tf.keras.Input((shape[3], shape[4]), name='input_baseline') 
    input_layer_samples  = tf.keras.Input((shape[6], shape[7]), name='input_sample') 

    #baseline

    conv_baseline = custom_CNN_layer(input_layer_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
    conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
    conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
    conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
    conv_baseline = custom_CNN_layer(conv_baseline, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')

    conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    # conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    # conv_baseline = custom_CNN_layer(conv_baseline, start_neuron * 4, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    conv_baseline = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(conv_baseline)
    conv_baseline = tf.keras.layers.Dropout(dropout)(conv_baseline)

    conv_baseline = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(conv_baseline)
    conv_baseline = tf.keras.layers.Dropout(dropout)(conv_baseline)
    conv_baseline = tf.keras.layers.Flatten()(conv_baseline)

    #samples
    conv_sample  = custom_CNN_layer(input_layer_samples, start_neuron, kernel_size = 3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
    conv_sample  = custom_CNN_layer(conv_sample, start_neuron , kernel_size =  3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')
    conv_sample  = custom_CNN_layer(conv_sample, start_neuron , kernel_size =  3, strides_size=1, max_pool_size=2, dropout=0.3, padding='same')

    conv_sample  = custom_CNN_layer(conv_sample, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    conv_sample  = custom_CNN_layer(conv_sample, start_neuron * 2, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    conv_sample  = custom_CNN_layer(conv_sample, start_neuron * 4, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
    # conv_sample = tf.keras.layers.Flatten()(conv_sample)
    conv_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(conv_sample)
    conv_sample = tf.keras.layers.Dropout(dropout)(conv_sample)

    conv_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(conv_sample)
    conv_sample = tf.keras.layers.Dropout(dropout)(conv_sample)
    conv_sample = tf.keras.layers.Flatten()(conv_sample)
    
    concat_layer = tf.keras.layers.Concatenate()([conv_baseline, conv_sample, input_layer_demo])
    
    output_layer = tf.keras.layers.Dense(start_neuron*8,activation=tf.keras.layers.LeakyReLU())(concat_layer)
    output_layer = tf.keras.layers.Dropout(dropout)(output_layer)
    output_layer = tf.keras.layers.Dense(start_neuron*8,activation=tf.keras.layers.LeakyReLU())(output_layer)
    output_layer = tf.keras.layers.Dropout(dropout)(output_layer)
    
    output_0 = tf.keras.layers.Dense(3, activation='softmax', name='difficulty')(output_layer)


    model = tf.keras.Model(inputs=[input_layer_demo, input_layer_baseline, input_layer_samples], outputs=[output_0])
    #loss_weights = [scaling_factors[0]*5,scaling_factors[1],scaling_factors[2],scaling_factors[3],scaling_factors[4]]   
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer = 'adam',loss = ['mae','mae','mae','mae','mae'],loss_weights=loss_weights)
    return model

# %%
reduce_LR_On_Plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=PATIENCE//2,verbose=1, min_delta=0.00001,)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights = True, mode = 'min')

# %%
current_shape = X_train_demo.shape + X_train_1_eye.shape + X_train_2_eye.shape
current_shape
# Out:
# (2480, 17, 2480, 60000, 5, 2480, 7500, 4)

# %%
model_eye = baseline_CNN(current_shape)
model_eye.summary()

history = model_eye.fit([X_train_demo,X_train_1_eye,X_train_2_eye], [Y_train_dif], 
                    epochs=EPOCHS, batch_size=BATCH_SIZE,verbose=1, shuffle=True, validation_split = 0.2, callbacks=[reduce_LR_On_Plateau,early_stopping])
# Out:
# 2024-09-05 22:51:11.127005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22757 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:1b:00.0, compute capability: 7.5
# 2024-09-05 22:51:11.127483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22757 MB memory:  -> device: 1, name: Quadro RTX 6000, pci bus id: 0000:1c:00.0, compute capability: 7.5
# 2024-09-05 22:51:11.127928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22757 MB memory:  -> device: 2, name: Quadro RTX 6000, pci bus id: 0000:1d:00.0, compute capability: 7.5
# 2024-09-05 22:51:11.128388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22757 MB memory:  -> device: 3, name: Quadro RTX 6000, pci bus id: 0000:1e:00.0, compute capability: 7.5
# 2024-09-05 22:51:11.128828: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 22757 MB memory:  -> device: 4, name: Quadro RTX 6000, pci bus id: 0000:3d:00.0, compute capability: 7.5
# 2024-09-05 22:51:11.129280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 22757 MB memory:  -> device: 5, name: Quadro RTX 6000, pci bus id: 0000:3f:00.0, compute capability: 7.5
# 2024-09-05 22:51:11.129710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 22757 MB memory:  -> device: 6, name: Quadro RTX 6000, pci bus id: 0000:40:00.0, compute capability: 7.5
# 2024-09-05 22:51:11.130143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 22757 MB memory:  -> device: 7, name: Quadro RTX 6000, pci bus id: 0000:41:00.0, compute capability: 7.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model_eye = baseline_CNN(current_shape)
#       2 model_eye.summary()
#       4 history = model_eye.fit([X_train_demo,X_train_1_eye,X_train_2_eye], [Y_train_dif],
#       5                     epochs=EPOCHS, batch_size=BATCH_SIZE,verbose=1, shuffle=True, validation_split = 0.2, callbacks=[reduce_LR_On_Plateau,early_stopping])
#
# Cell In[17], line 37, in baseline_CNN(shape, start_neuron, kernel_size, strides_size, max_pool_size, dropout, padding)
#      35 conv_sample  = custom_CNN_layer(conv_sample, start_neuron * 4, kernel_size = 5, strides_size=1, max_pool_size=3, dropout=0.3, padding='same')
#      36 conv_sample = tf.keras.layers.Flatten()(conv_sample)
# ---> 37 conv_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(conv_sample)
#      38 conv_sample = tf.keras.layers.Dropout(dropout)(conv_sample)
#      40 conv_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(conv_sample)
#
# File ~/.conda/envs/tf/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.conda/envs/tf/lib/python3.12/site-packages/keras/src/layers/input_spec.py:186, in assert_input_compatibility(input_spec, inputs, layer_name)
#     184 if spec.ndim is not None and not spec.allow_last_axis_squeeze:
#     185     if ndim != spec.ndim:
# --> 186         raise ValueError(
#     187             f'Input {input_index} of layer "{layer_name}" '
#     188             "is incompatible with the layer: "
#     189             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#     190             f"Full shape received: {shape}"
#     191         )
#     192 if spec.max_ndim is not None:
#     193     if ndim is not None and ndim > spec.max_ndim:
#
# ValueError: Input 0 of layer "bidirectional_2" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 2240)

# %%
current_shape[4]

# %% [markdown]
# ## Evaluation

# %%
Y_pred = model_eye.predict([X_test_demo,X_test_1_eye,X_test_2_eye])
Y_pred

# %%
np.argmax(Y_pred,axis=1)

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.savefig(OUTPUT_DIR + 'Loss for Eye')
plt.show()

# %%
# Calculate the confusion matrix
cm = confusion_matrix(Y_test_dif, np.argmax(Y_pred,axis=1))

f1 = f1_score(Y_test_dif,  np.argmax(Y_pred,axis=1), average='weighted')
accuracy = accuracy_score(Y_test_dif,  np.argmax(Y_pred,axis=1))
mcc = matthews_corrcoef(Y_test_dif,  np.argmax(Y_pred,axis=1))

# Display the confusion matrix using Matplotlib
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix\nF1 Score: {f1:.2f}, MCC: {mcc:.2f}, Accuracy: {accuracy:.2f}")

plt.savefig(OUTPUT_DIR + 'Confusion Matrix for Eye')

plt.show()

# %%
def permutation_importance(model, X_test_list, Y_test, accuracy_original, data_index, feature_index):
    accuracy_list = []
    for i in range(5):
        X_test_shuffled = X_test_list[data_index].copy()
        if data_index == 0:
            #if X_demo, shuffle 2nd dimension
            np.random.shuffle(X_test_shuffled[:, feature_index])
        else:
            #if not X_demo, shuffle 3nd dimension
            np.random.shuffle(X_test_shuffled[:,:, feature_index])
            
        X_test_list[data_index] = X_test_shuffled
        # Get predictions with shuffled feature
        Y_pred_shuffled = model.predict([X_test_list[0], X_test_list[1], X_test_list[2] ])
        accuracy_shuffled = accuracy_score(Y_test, np.argmax(Y_pred_shuffled, axis=1))

        # Calculate accuracy drop
        accuracy_list.append(accuracy_original - accuracy_shuffled)
        
    return np.mean(accuracy_list)

# %%
Y_pred = model_eye.predict([X_test_demo, X_test_1_eye, X_test_2_eye])
accuracy_original = accuracy_score(Y_test_dif, np.argmax(Y_pred, axis=1))
accuracy_list = [0] *3

for i in range(3):
    temp_list = []
    temp_list.append(accuracy_original)
    X_test_list = [X_test_demo, X_test_1_eye, X_test_2_eye].copy()

    #use 2nd dimension for X_demo and 3rd for other
    if i == 0:
        current_dimension = 1
    else:
        current_dimension = 2
    
    for j in range(X_test_list[i].shape[current_dimension]):
        print(i, '  ', j)
        mean_accuracy = permutation_importance(model_eye, X_test_list, Y_test_dif, accuracy_original, i, j)
        temp_list.append(mean_accuracy)
        
    accuracy_list[i] = temp_list

# %%
subplot_title = ['Demongraphic','Baseline','Samples']
X_ticks = [0] * 3
X_ticks[0] = ['Baseline'] + ['Age', 'Gender', 'Race', 'Education', 'Smote_frequently',
       'Caffeine_Consumption', 'Q2_How long played games',
       'Q3_how often video games?',
       'Q4_how many hours playing video games?',
       'Q5_When you play video games how many hours',
       'Q6_How skilled',
       'Q7_your experience playing video games.',
       'Q8_First-person shooter',
       'Q9_Realistic military',
       'Q10_Driving or Racing',
       'Q11_Strategy',
       'Q12_Role-playing']
X_ticks[1] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y','missing_percentage']
X_ticks[2] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y']

# %%
# Number of subplots (based on the first dimension)
n_subplots = len(accuracy_list)

# Create subplots
fig, axs = plt.subplots(n_subplots, 1, figsize=(8, 15))

# Plot each subplot
for i in range(n_subplots):
    axs[i].bar(range(len(accuracy_list[i])), accuracy_list[i], color='skyblue')
    axs[i].set_title(subplot_title[i])
    axs[i].set_xlabel('Features')
    axs[i].set_ylabel('Accuracy')
    axs[i].set_xticks(range(len(X_ticks[i])))
    axs[i].set_xticklabels(X_ticks[i], rotation=10, fontsize=8)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig(OUTPUT_DIR + 'Feature Importance for Eye')
# Show the plot
plt.show()

# %% [markdown]
# # Model 2 Wavelet

# %%
reduce_LR_On_Plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=PATIENCE//2,verbose=1, min_delta=0.00001,)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights = True, mode = 'min')

# %%
print(X_train_1_eye_wavelet.dtype)
print(X_train_2_eye.dtype)

# %%
current_shape = X_train_demo.shape + X_train_1_eye_wavelet.shape + X_train_2_eye_wavelet.shape
current_shape

# %%
model_eye_wavelet = baseline_CNN(current_shape)
model_eye_wavelet.summary()

history = model_eye_wavelet.fit([X_train_demo,X_train_1_eye_wavelet,X_train_2_eye], [Y_train_dif], 
                    epochs=EPOCHS, batch_size=BATCH_SIZE,verbose=1, shuffle=True, validation_split = 0.2, callbacks=[reduce_LR_On_Plateau,early_stopping])

# %%
Y_pred = model_eye_wavelet.predict([X_test_demo,X_test_1_eye_wavelet,X_test_2_eye_wavelet])
Y_pred

# %%
np.argmax(Y_pred,axis=1)

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.savefig(OUTPUT_DIR + 'Loss for Eye_wavelet')
plt.show()

# %%
# Calculate the confusion matrix
cm = confusion_matrix(Y_test_dif, np.argmax(Y_pred,axis=1))

f1 = f1_score(Y_test_dif,  np.argmax(Y_pred,axis=1), average='weighted')
accuracy = accuracy_score(Y_test_dif,  np.argmax(Y_pred,axis=1))
mcc = matthews_corrcoef(Y_test_dif,  np.argmax(Y_pred,axis=1))

# Display the confusion matrix using Matplotlib
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix\nF1 Score: {f1:.2f}, MCC: {mcc:.2f}, Accuracy: {accuracy:.2f}")

plt.savefig(OUTPUT_DIR + 'Confusion Matrix for Eye_wavelet')

plt.show()

# %%
def permutation_importance(model, X_test_list, Y_test, accuracy_original, data_index, feature_index):
    accuracy_list = []
    for i in range(5):
        X_test_shuffled = X_test_list[data_index].copy()
        if data_index == 0:
            #if X_demo, shuffle 2nd dimension
            np.random.shuffle(X_test_shuffled[:, feature_index])
        else:
            #if not X_demo, shuffle 3nd dimension
            np.random.shuffle(X_test_shuffled[:,:, feature_index])
            
        X_test_list[data_index] = X_test_shuffled
        # Get predictions with shuffled feature
        Y_pred_shuffled = model.predict([X_test_list[0], X_test_list[1], X_test_list[2] ])
        accuracy_shuffled = accuracy_score(Y_test, np.argmax(Y_pred_shuffled, axis=1))

        # Calculate accuracy drop
        accuracy_list.append(accuracy_original - accuracy_shuffled)
        
    return np.mean(accuracy_list)

# %%
Y_pred = model_eye_wavelet.predict([X_test_demo, X_test_1_eye_wavelet, X_test_2_eye_wavelet])
accuracy_original = accuracy_score(Y_test_dif, np.argmax(Y_pred, axis=1))
accuracy_list = [0] *3

for i in range(3):
    temp_list = []
    temp_list.append(accuracy_original)
    X_test_list = [X_test_demo, X_test_1_eye_wavelet, X_test_2_eye_wavelet].copy()

    #use 2nd dimension for X_demo and 3rd for other
    if i == 0:
        current_dimension = 1
    else:
        current_dimension = 2
    
    for j in range(X_test_list[i].shape[current_dimension]):
        print(i, '  ', j)
        mean_accuracy = permutation_importance(model_eye_wavelet, X_test_list, Y_test_dif, accuracy_original, i, j)
        temp_list.append(mean_accuracy)
        
    accuracy_list[i] = temp_list

# %%
subplot_title = ['Demongraphic','Baseline','Samples']
X_ticks = [0] * 3
X_ticks[0] = ['Baseline'] + ['Age', 'Gender', 'Race', 'Education', 'Smote_frequently',
       'Caffeine_Consumption', 'Q2_How long played games',
       'Q3_how often video games?',
       'Q4_how many hours playing video games?',
       'Q5_When you play video games how many hours',
       'Q6_How skilled',
       'Q7_your experience playing video games.',
       'Q8_First-person shooter',
       'Q9_Realistic military',
       'Q10_Driving or Racing',
       'Q11_Strategy',
       'Q12_Role-playing']
X_ticks[1] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y','missing_percentage']
X_ticks[2] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y']

# %%
# Number of subplots (based on the first dimension)
n_subplots = len(accuracy_list)

# Create subplots
fig, axs = plt.subplots(n_subplots, 1, figsize=(8, 15))

# Plot each subplot
for i in range(n_subplots):
    axs[i].bar(range(len(accuracy_list[i])), accuracy_list[i], color='skyblue')
    axs[i].set_title(subplot_title[i])
    axs[i].set_xlabel('Features')
    axs[i].set_ylabel('Accuracy')
    axs[i].set_xticks(range(len(X_ticks[i])))
    axs[i].set_xticklabels(X_ticks[i], rotation=10, fontsize=8)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig(OUTPUT_DIR + 'Feature Importance for Eye_wavelet')
# Show the plot
plt.show()

# %% [markdown]
# # Model ECG

# %%
def custom_CNN_layer(input_layer, start_neuron = 16, kernel_size=9, strides_size=1, max_pool_size=5, dropout=0.3, padding='valid'):
    cnn_layer = tf.keras.layers.Conv1D(start_neuron, kernel_size, strides=strides_size,  padding=padding, activation=tf.keras.layers.LeakyReLU(),kernel_regularizer=tf.keras.regularizers.l2(0.01))(input_layer)
    #cnn_layer = tf.keras.layers.Conv1D(start_neuron, kernel_size, strides=strides_size,  padding=padding, activation=tf.keras.layers.LeakyReLU(),kernel_regularizer=tf.keras.regularizers.l2(0.01))(cnn_layer)
    cnn_layer = tf.keras.layers.MaxPool1D(max_pool_size,  padding=padding)(cnn_layer)
    cnn_layer = tf.keras.layers.BatchNormalization()(cnn_layer)
    cnn_layer = tf.keras.layers.Dropout(dropout)(cnn_layer)
    return cnn_layer

# %%
#create model
def baseline_CNN(shape, start_neuron = 16, kernel_size=9, strides_size=1, max_pool_size=5, dropout=0.3, padding='valid'):    

    input_layer_demo     = tf.keras.Input((shape[1],), name='input_demo') 
    input_layer_baseline = tf.keras.Input((shape[3], shape[4]), name='input_baseline') 
    input_layer_samples  = tf.keras.Input((shape[6], shape[7]), name='input_sample') 

    #baseline
    
    lstm_baseline = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron, return_sequences=True))(input_layer_baseline)
    lstm_baseline = tf.keras.layers.Dropout(dropout)(lstm_baseline)
    lstm_baseline = tf.keras.layers.MaxPool1D(25)(lstm_baseline)

    lstm_baseline = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron, return_sequences=True))(lstm_baseline)
    lstm_baseline = tf.keras.layers.Dropout(dropout)(lstm_baseline)
    lstm_baseline = tf.keras.layers.MaxPool1D(10)(lstm_baseline)

    lstm_baseline = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron, return_sequences=True))(lstm_baseline)
    lstm_baseline = tf.keras.layers.Dropout(dropout)(lstm_baseline)
    lstm_baseline = tf.keras.layers.MaxPool1D(5)(lstm_baseline)
    
    lstm_baseline = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(lstm_baseline)
    lstm_baseline = tf.keras.layers.Dropout(dropout)(lstm_baseline)
    lstm_baseline = tf.keras.layers.Flatten()(lstm_baseline)

    #samples
    lstm_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron, return_sequences=True))(input_layer_samples)
    lstm_sample = tf.keras.layers.Dropout(dropout)(lstm_sample)
    lstm_sample = tf.keras.layers.MaxPool1D(25)(lstm_sample)

    lstm_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron, return_sequences=True))(lstm_sample)
    lstm_sample = tf.keras.layers.Dropout(dropout)(lstm_sample)
    lstm_sample = tf.keras.layers.MaxPool1D(5)(lstm_sample)

    lstm_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron, return_sequences=True))(lstm_sample)
    lstm_sample = tf.keras.layers.Dropout(dropout)(lstm_sample)
    lstm_sample = tf.keras.layers.MaxPool1D(2)(lstm_sample)
    
    lstm_sample = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(start_neuron * 2, return_sequences=True))(lstm_sample)
    lstm_sample = tf.keras.layers.Dropout(dropout)(lstm_sample)
    lstm_sample = tf.keras.layers.Flatten()(lstm_sample)
    
    #Econcat_layer = tf.keras.layers.Concatenate()([conv_baseline, conv_sample, input_layer_demo])
    concat_layer = tf.keras.layers.Concatenate()([lstm_sample, input_layer_demo])
    
    output_layer = tf.keras.layers.Dense(start_neuron*8,activation=tf.keras.layers.LeakyReLU())(concat_layer)
    output_layer = tf.keras.layers.Dropout(dropout)(output_layer)
    output_layer = tf.keras.layers.Dense(start_neuron*8,activation=tf.keras.layers.LeakyReLU())(output_layer)
    output_layer = tf.keras.layers.Dropout(dropout)(output_layer)
    
    output_0 = tf.keras.layers.Dense(3, activation='softmax', name='difficulty')(output_layer)


    model = tf.keras.Model(inputs=[input_layer_demo, input_layer_baseline, input_layer_samples], outputs=[output_0])
    #loss_weights = [scaling_factors[0]*5,scaling_factors[1],scaling_factors[2],scaling_factors[3],scaling_factors[4]]   
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer = 'adam',loss = ['mae','mae','mae','mae','mae'],loss_weights=loss_weights)
    return model

# %%
reduce_LR_On_Plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=PATIENCE//2,verbose=1, min_delta=0.00001,)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights = True, mode = 'min')

# %%
current_shape = X_train_demo.shape + X_train_1_ecg.shape + X_train_2_ecg.shape
current_shape
# Out:
# (2480, 17, 2480, 60000, 7, 2480, 7500, 7)

# %%
model_ecg = baseline_CNN(current_shape)
model_ecg.summary()

history = model_ecg.fit([X_train_demo,X_train_1_ecg,X_train_2_ecg], [Y_train_dif], 
                    epochs=EPOCHS, batch_size=BATCH_SIZE,verbose=1, shuffle=True, validation_split = 0.2, callbacks=[reduce_LR_On_Plateau,early_stopping])
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_sample        │ (None, 7500, 7)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_53    │ (None, 7500, 32)  │      3,072 │ input_sample[0][… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_130         │ (None, 7500, 32)  │          0 │ bidirectional_53… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_89    │ (None, 300, 32)   │          0 │ dropout_130[0][0] │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_54    │ (None, 300, 32)   │      6,272 │ max_pooling1d_89… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_131         │ (None, 300, 32)   │          0 │ bidirectional_54… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_90    │ (None, 60, 32)    │          0 │ dropout_131[0][0] │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_55    │ (None, 60, 32)    │      6,272 │ max_pooling1d_90… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_132         │ (None, 60, 32)    │          0 │ bidirectional_55… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_91    │ (None, 30, 32)    │          0 │ dropout_132[0][0] │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_56    │ (None, 30, 64)    │     16,640 │ max_pooling1d_91… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_133         │ (None, 30, 64)    │          0 │ bidirectional_56… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_27          │ (None, 1920)      │          0 │ dropout_133[0][0] │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_demo          │ (None, 17)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 1937)      │          0 │ flatten_27[0][0], │
# │ (Concatenate)       │                   │            │ input_demo[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 128)       │    248,064 │ concatenate_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_134         │ (None, 128)       │          0 │ dense_22[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 128)       │     16,512 │ dropout_134[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_135         │ (None, 128)       │          0 │ dense_23[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_baseline      │ (None, 60000, 7)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ difficulty (Dense)  │ (None, 3)         │        387 │ dropout_135[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 297,219 (1.13 MB)
#  Trainable params: 297,219 (1.13 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 52s 413ms/step - accuracy: 0.3346 - loss: 1.1914 - val_accuracy: 0.3569 - val_loss: 1.1249 - learning_rate: 0.0010
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.3331 - loss: 1.1284 - val_accuracy: 0.3145 - val_loss: 1.1010 - learning_rate: 0.0010
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step - accuracy: 0.3584 - loss: 1.1064 - val_accuracy: 0.3145 - val_loss: 1.1009 - learning_rate: 0.0010
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 341ms/step - accuracy: 0.3597 - loss: 1.1048 - val_accuracy: 0.3488 - val_loss: 1.0988 - learning_rate: 0.0010
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 342ms/step - accuracy: 0.3679 - loss: 1.0961 - val_accuracy: 0.3669 - val_loss: 1.0976 - learning_rate: 0.0010
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 340ms/step - accuracy: 0.3499 - loss: 1.1069 - val_accuracy: 0.3165 - val_loss: 1.1015 - learning_rate: 0.0010
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 342ms/step - accuracy: 0.3403 - loss: 1.1011 - val_accuracy: 0.3407 - val_loss: 1.1099 - learning_rate: 0.0010
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 348ms/step - accuracy: 0.3394 - loss: 1.1004 - val_accuracy: 0.3569 - val_loss: 1.1009 - learning_rate: 0.0010
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 342ms/step - accuracy: 0.3454 - loss: 1.1023 - val_accuracy: 0.3589 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 341ms/step - accuracy: 0.3332 - loss: 1.1064 - val_accuracy: 0.3427 - val_loss: 1.1013 - learning_rate: 0.0010
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 345ms/step - accuracy: 0.3690 - loss: 1.0922 - val_accuracy: 0.3306 - val_loss: 1.1017 - learning_rate: 0.0010
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 345ms/step - accuracy: 0.3582 - loss: 1.0955 - val_accuracy: 0.3125 - val_loss: 1.1048 - learning_rate: 0.0010
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 343ms/step - accuracy: 0.3542 - loss: 1.1012 - val_accuracy: 0.3145 - val_loss: 1.1008 - learning_rate: 0.0010
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 344ms/step - accuracy: 0.3641 - loss: 1.0975 - val_accuracy: 0.3609 - val_loss: 1.1065 - learning_rate: 0.0010
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.3717 - loss: 1.0966
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 346ms/step - accuracy: 0.3713 - loss: 1.0967 - val_accuracy: 0.3468 - val_loss: 1.0991 - learning_rate: 0.0010
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 344ms/step - accuracy: 0.3667 - loss: 1.0946 - val_accuracy: 0.3690 - val_loss: 1.0993 - learning_rate: 5.0000e-04
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 337ms/step - accuracy: 0.3438 - loss: 1.0964 - val_accuracy: 0.3609 - val_loss: 1.0997 - learning_rate: 5.0000e-04
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 340ms/step - accuracy: 0.3628 - loss: 1.0950 - val_accuracy: 0.3609 - val_loss: 1.1000 - learning_rate: 5.0000e-04
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 346ms/step - accuracy: 0.3833 - loss: 1.0898 - val_accuracy: 0.3306 - val_loss: 1.1010 - learning_rate: 5.0000e-04
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 346ms/step - accuracy: 0.3939 - loss: 1.0862 - val_accuracy: 0.3246 - val_loss: 1.1074 - learning_rate: 5.0000e-04
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 341ms/step - accuracy: 0.3717 - loss: 1.0981 - val_accuracy: 0.3589 - val_loss: 1.1015 - learning_rate: 5.0000e-04
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 344ms/step - accuracy: 0.3661 - loss: 1.0930 - val_accuracy: 0.3569 - val_loss: 1.1024 - learning_rate: 5.0000e-04
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 345ms/step - accuracy: 0.3670 - loss: 1.0932 - val_accuracy: 0.3488 - val_loss: 1.1017 - learning_rate: 5.0000e-04
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 343ms/step - accuracy: 0.3714 - loss: 1.0893 - val_accuracy: 0.3468 - val_loss: 1.1007 - learning_rate: 5.0000e-04
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.4004 - loss: 1.0873
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 343ms/step - accuracy: 0.4002 - loss: 1.0873 - val_accuracy: 0.3488 - val_loss: 1.1038 - learning_rate: 5.0000e-04

# %%
Y_pred = model_ecg.predict([X_test_demo,X_test_1_ecg,X_test_2_ecg])
Y_pred
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step
# array([[0.31224972, 0.33200672, 0.3557435 ],
#        [0.27848467, 0.3562692 , 0.36524612],
#        [0.27840593, 0.35608912, 0.3655049 ],
#        ...,
#        [0.32547733, 0.30031437, 0.37420833],
#        [0.32827717, 0.30151895, 0.37020388],
#        [0.31227618, 0.3259219 , 0.3618019 ]], dtype=float32)

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.savefig(OUTPUT_DIR + 'Loss for Ecg')
plt.show()

# %%
# Calculate the confusion matrix
cm = confusion_matrix(Y_test_dif, np.argmax(Y_pred,axis=1))

f1 = f1_score(Y_test_dif,  np.argmax(Y_pred,axis=1), average='weighted')
accuracy = accuracy_score(Y_test_dif,  np.argmax(Y_pred,axis=1))
mcc = matthews_corrcoef(Y_test_dif,  np.argmax(Y_pred,axis=1))

# Display the confusion matrix using Matplotlib
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix\nF1 Score: {f1:.2f}, MCC: {mcc:.2f}, Accuracy: {accuracy:.2f}")

plt.savefig(OUTPUT_DIR + 'Confusion Matrix for Ecg')

plt.show()

# %%
def permutation_importance(model, X_test_list, Y_test, accuracy_original, data_index, feature_index):
    accuracy_list = []
    for i in range(5):
        X_test_shuffled = X_test_list[data_index].copy()
        if data_index == 0:
            #if X_demo, shuffle 2nd dimension
            np.random.shuffle(X_test_shuffled[:, feature_index])
        else:
            #if not X_demo, shuffle 3nd dimension
            np.random.shuffle(X_test_shuffled[:,:, feature_index])
            
        X_test_list[data_index] = X_test_shuffled
        # Get predictions with shuffled feature
        Y_pred_shuffled = model.predict([X_test_list[0], X_test_list[1], X_test_list[2] ])
        accuracy_shuffled = accuracy_score(Y_test, np.argmax(Y_pred_shuffled, axis=1))

        # Calculate accuracy drop
        accuracy_list.append(accuracy_original - accuracy_shuffled)
        
    return np.mean(accuracy_list)

# %%
Y_pred = model_ecg.predict([X_test_demo, X_test_1_ecg, X_test_2_ecg])
accuracy_original = accuracy_score(Y_test_dif, np.argmax(Y_pred, axis=1))
accuracy_list = [0] *3

for i in range(3):
    temp_list = []
    temp_list.append(accuracy_original)
    X_test_list = [X_test_demo, X_test_1_ecg, X_test_2_ecg].copy()

    #use 2nd dimension for X_demo and 3rd for other
    if i == 0:
        current_dimension = 1
    else:
        current_dimension = 2
    
    for j in range(X_test_list[i].shape[current_dimension]):
        print(i, '  ', j)
        mean_accuracy = permutation_importance(model_ecg, X_test_list, Y_test_dif, accuracy_original, i, j)
        temp_list.append(mean_accuracy)
        
    accuracy_list[i] = temp_list
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 0    0
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 0    1
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    2
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    3
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    4
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step
# 0    6
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    7
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    8
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    9
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 0    10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 0    11
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 0    12
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 0    13
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 0    14
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 0    15
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 0    16
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 1    0
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 1    1
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 1    2
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 1    3
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 1    4
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 1    5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 1    6
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 2    0
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 2    1
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 2    2
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 2    3
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 2    4
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 2    5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 2    6
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step

# %%
subplot_title = ['Demongraphic','Baseline','Samples']
X_ticks = [0] * 3
X_ticks[0] = ['Baseline'] + ['Age', 'Gender', 'Race', 'Education', 'Smote_frequently',
       'Caffeine_Consumption', 'Q2_How long played games',
       'Q3_how often video games?',
       'Q4_how many hours playing video games?',
       'Q5_When you play video games how many hours',
       'Q6_How skilled',
       'Q7_your experience playing video games.',
       'Q8_First-person shooter',
       'Q9_Realistic military',
       'Q10_Driving or Racing',
       'Q11_Strategy',
       'Q12_Role-playing']
X_ticks[1] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y','missing_percentage']
X_ticks[2] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y']

# %%
# Number of subplots (based on the first dimension)
n_subplots = len(accuracy_list)

# Create subplots
fig, axs = plt.subplots(n_subplots, 1, figsize=(8, 15))

# Plot each subplot
for i in range(n_subplots):
    axs[i].bar(range(len(accuracy_list[i])), accuracy_list[i], color='skyblue')
    axs[i].set_title(subplot_title[i])
    axs[i].set_xlabel('Features')
    axs[i].set_ylabel('Accuracy')
    axs[i].set_xticks(range(len(X_ticks[i])))
    axs[i].set_xticklabels(X_ticks[i], rotation=10, fontsize=8)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig(OUTPUT_DIR + 'Feature Importance for Ecg')
# Show the plot
plt.show()

# %% [markdown]
# # Model ECG_wavelet

# %%
reduce_LR_On_Plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=PATIENCE//2,verbose=1, min_delta=0.00001,)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights = True, mode = 'min')

# %%
current_shape = X_train_demo.shape + X_train_1_ecg_wavelet.shape + X_train_2_ecg_wavelet.shape
current_shape

# %%
model_ecg_wavelet = baseline_CNN(current_shape)
model_ecg_wavelet.summary()

history = model_ecg_wavelet.fit([X_train_demo,X_train_1_ecg_wavelet,X_train_2_ecg_wavelet], [Y_train_dif], 
                    epochs=EPOCHS, batch_size=BATCH_SIZE,verbose=1, shuffle=True, validation_split = 0.2, callbacks=[reduce_LR_On_Plateau,early_stopping])

# %%
Y_pred = model_ecg_wavelet.predict([X_test_demo,X_test_1_ecg_wavelet,X_test_2_ecg_wavelet])
Y_pred

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.savefig(OUTPUT_DIR + 'Loss for Ecg_wavelet')
plt.show()

# %%
# Calculate the confusion matrix
cm = confusion_matrix(Y_test_dif, np.argmax(Y_pred,axis=1))

f1 = f1_score(Y_test_dif,  np.argmax(Y_pred,axis=1), average='weighted')
accuracy = accuracy_score(Y_test_dif,  np.argmax(Y_pred,axis=1))
mcc = matthews_corrcoef(Y_test_dif,  np.argmax(Y_pred,axis=1))

# Display the confusion matrix using Matplotlib
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix\nF1 Score: {f1:.2f}, MCC: {mcc:.2f}, Accuracy: {accuracy:.2f}")

plt.savefig(OUTPUT_DIR + 'Confusion Matrix for Ecg_wavelet')

plt.show()

# %%
def permutation_importance(model, X_test_list, Y_test, accuracy_original, data_index, feature_index):
    accuracy_list = []
    for i in range(5):
        X_test_shuffled = X_test_list[data_index].copy()
        if data_index == 0:
            #if X_demo, shuffle 2nd dimension
            np.random.shuffle(X_test_shuffled[:, feature_index])
        else:
            #if not X_demo, shuffle 3nd dimension
            np.random.shuffle(X_test_shuffled[:,:, feature_index])
            
        X_test_list[data_index] = X_test_shuffled
        # Get predictions with shuffled feature
        Y_pred_shuffled = model.predict([X_test_list[0], X_test_list[1], X_test_list[2] ])
        accuracy_shuffled = accuracy_score(Y_test, np.argmax(Y_pred_shuffled, axis=1))

        # Calculate accuracy drop
        accuracy_list.append(accuracy_original - accuracy_shuffled)
        
    return np.mean(accuracy_list)

# %%
Y_pred = model_ecg_wavelet.predict([X_test_demo, X_test_1_ecg_wavelet, X_test_2_ecg_wavelet])
accuracy_original = accuracy_score(Y_test_dif, np.argmax(Y_pred, axis=1))
accuracy_list = [0] *3

for i in range(3):
    temp_list = []
    temp_list.append(accuracy_original)
    X_test_list = [X_test_demo, X_test_1_ecg_wavelet, X_test_2_ecg_wavelet].copy()

    #use 2nd dimension for X_demo and 3rd for other
    if i == 0:
        current_dimension = 1
    else:
        current_dimension = 2
    
    for j in range(X_test_list[i].shape[current_dimension]):
        print(i, '  ', j)
        mean_accuracy = permutation_importance(model_ecg_wavelet, X_test_list, Y_test_dif, accuracy_original, i, j)
        temp_list.append(mean_accuracy)
        
    accuracy_list[i] = temp_list

# %%
subplot_title = ['Demongraphic','Baseline','Samples']
X_ticks = [0] * 3
X_ticks[0] = ['Baseline'] + ['Age', 'Gender', 'Race', 'Education', 'Smote_frequently',
       'Caffeine_Consumption', 'Q2_How long played games',
       'Q3_how often video games?',
       'Q4_how many hours playing video games?',
       'Q5_When you play video games how many hours',
       'Q6_How skilled',
       'Q7_your experience playing video games.',
       'Q8_First-person shooter',
       'Q9_Realistic military',
       'Q10_Driving or Racing',
       'Q11_Strategy',
       'Q12_Role-playing']
X_ticks[1] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y','missing_percentage']
X_ticks[2] = ['Baseline'] + ['Pupil_left','Pupil_right','Gaze_X','Gaze_Y']

# %%
# Number of subplots (based on the first dimension)
n_subplots = len(accuracy_list)

# Create subplots
fig, axs = plt.subplots(n_subplots, 1, figsize=(8, 15))

# Plot each subplot
for i in range(n_subplots):
    axs[i].bar(range(len(accuracy_list[i])), accuracy_list[i], color='skyblue')
    axs[i].set_title(subplot_title[i])
    axs[i].set_xlabel('Features')
    axs[i].set_ylabel('Accuracy')
    axs[i].set_xticks(range(len(X_ticks[i])))
    axs[i].set_xticklabels(X_ticks[i], rotation=10, fontsize=8)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig(OUTPUT_DIR + 'Feature Importance for Ecg_wavelet')
# Show the plot
plt.show()
